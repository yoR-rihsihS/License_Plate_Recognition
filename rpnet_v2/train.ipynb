# %%
import os
import pickle
import pandas as pd
from PIL import Image
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

from san_18_04_2 import Recognition_Module
# Out:
# /data2/home/shishirm/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
device = 'cuda:0'
torch.cuda.empty_cache()

prov_Num, alpha_Num, ad_Num = 38, 25, 35

# %%
def save_file(history, path):
    with open(path, 'wb') as file:
        pickle.dump(history, file)

def load_file(path):
    with open(path, 'rb') as file:
        history = pickle.load(file)
    return history

# %%
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data_frame = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        image_path = self.data_frame.iloc[idx, 0]
        label = [x for x in self.data_frame.iloc[idx, 5:]] # license plate chracters' indices

        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, torch.tensor(label, dtype=torch.long)

# %%
transform_list = [
    transforms.RandomRotation(30),
    transforms.ColorJitter(brightness=0.2),
    transforms.ColorJitter(contrast=0.2),
    transforms.ColorJitter(saturation=0.2),
    transforms.ColorJitter(hue=0.2),
    transforms.GaussianBlur(kernel_size=5, sigma=(0.1, 2.0)),
    transforms.RandomAdjustSharpness(sharpness_factor=2),
    transforms.RandomInvert(p=0.5),
]

transform0 = transforms.Compose([
    transforms.Resize((480, 480)),
    transforms.ToTensor(),
])

transform1 = transforms.Compose([
    transforms.Resize((480, 480)),
    transforms.ToTensor(),
    transforms.RandomChoice(transform_list)
])

# %%
train_dataset = CustomDataset('../datasets/train.csv', transform = transform1)
valid_dataset = CustomDataset('../datasets/validate.csv', transform = transform0)

train_loader = DataLoader(train_dataset, batch_size=100, shuffle=True, num_workers=50, persistent_workers=True, prefetch_factor=10)
validation_loader = DataLoader(valid_dataset, batch_size=100, shuffle=False, num_workers=10, persistent_workers=True, prefetch_factor=10)

# %%
def validate_model(model, validation_loader, loss_fn):
    validation_loss = 0.0
    ch_correct = 0
    li_correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for image, label in validation_loader:
            image = image.to(device)
            label = label.to(device).T

            attn, pred_label = model(image)
            loss = loss_fn(pred_label[0], label[0])
            for i in range(1, 7):
                loss += loss_fn(pred_label[i], label[i])

            validation_loss += loss.item()

            predictions = [torch.argmax(curr, dim=1) for curr in pred_label]
            pred_license = torch.stack(predictions, dim=1).to(device)
            ch_equal = (label.T == pred_license)
            ch_correct += torch.sum(ch_equal).item()
            li_equal = torch.all(ch_equal, dim=1)
            li_correct += torch.sum(li_equal).item()
            total += image.shape[0]

    return validation_loss, 100 * ch_correct / (7 * total), 100 * li_correct / total

# %%
def train_model(model, opt, sch, loss_fn, train_loader, validation_loader, lr, num_epochs):
    history = {'train_loss' : [], 'val_loss' : [], 'train_ch_acc' : [], 'train_li_acc' : [], 'val_ch_acc' : [], 'val_li_acc' : []}

    optimizer = opt(model.parameters(), lr=lr, momentum=0.9)
    scheduler = sch(optimizer, step_size=6, gamma=0.1)

    if os.path.exists('./model/checkpoint.pth'):
        history = load_file('./model/history.pkl')
        checkpoint = torch.load('./model/checkpoint.pth', map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])

    with tqdm(total=num_epochs * len(train_loader)) as train_bar:
        for epoch in range(num_epochs):
            if len(history['train_loss']) > epoch:
                train_bar.set_description(f"Resuming")
                train_bar.update(len(train_loader))
                print(f"Epoch {epoch+1} \tTraining Loss : {history['train_loss'][epoch]} \tValidation Loss : {history['val_loss'][epoch]}")
                print(f"Train Ch Accuracy : {history['train_ch_acc'][epoch]} \tTrain Li Accuracy : {history['train_li_acc'][epoch]}")
                print(f"Validation Ch Accuracy : {history['val_ch_acc'][epoch]} \tValidation Li Accuracy : {history['val_li_acc'][epoch]}")
                print()
                continue
            
            train_bar.set_description(f"Training epoch {epoch+1}")
            model.train()
            train_loss = 0.0
            ch_correct = 0
            li_correct = 0
            total = 0
            for image, label in train_loader:
                image = image.to(device)
                label = label.to(device).T

                attn, pred_label = model(image)
                loss = loss_fn(pred_label[0], label[0])
                for i in range(1, 7):
                    loss += loss_fn(pred_label[i], label[i])

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                train_loss += loss.item()
                train_bar.update(1)

                predictions = [torch.argmax(curr, dim=1) for curr in pred_label]
                pred_license = torch.stack(predictions, dim=1).to(device)
                ch_equal = (label.T == pred_license)
                ch_correct += torch.sum(ch_equal).item()
                li_equal = torch.all(ch_equal, dim=1)
                li_correct += torch.sum(li_equal).item()
                total += image.shape[0]

            train_bar.set_description(f"Validating epoch {epoch+1}")
            val_loss, val_ch_acc, val_li_acc = validate_model(model, validation_loader, loss_fn)

            train_ch_acc = 100 * ch_correct / (7 * total)
            train_li_acc = 100 * li_correct / total

            print(f"Epoch {epoch+1} \tTraining Loss : {train_loss} \tValidation Loss : {val_loss}")
            print(f"Train Ch Accuracy : {train_ch_acc} \tTrain Li Accuracy : {train_li_acc}")
            print(f"Validation Ch Accuracy : {val_ch_acc} \tValidation Li Accuracy : {val_li_acc}")
            print()

            history['train_loss'].append(train_loss)
            history['val_loss'].append(val_loss)
            history['val_ch_acc'].append(val_ch_acc)
            history['val_li_acc'].append(val_li_acc)
            history['train_ch_acc'].append(train_ch_acc)
            history['train_li_acc'].append(train_li_acc)

            scheduler.step()

            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
            }, './model/checkpoint.pth')
            save_file(history, './model/history.pkl')

            if epoch % 5 == 4 and epoch >= 9:
                torch.save(model.state_dict(), "./model/prediction_module_"+str(epoch+1)+".pth")

    return history

# %%
model = Recognition_Module()
model.to(device)

num_parameters = sum(p.numel() for p in model.parameters())
print("Number of parameters =", num_parameters)

num_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Number of trainable parameters =", num_parameters)
# Out:
# Number of parameters = 16326064
# Number of trainable parameters = 16326064

# %%
opt = optim.SGD
loss_fn = nn.CrossEntropyLoss().to(device)
sch = optim.lr_scheduler.StepLR

# %%
history = train_model(model, opt, sch, loss_fn, train_loader, validation_loader, 0.01, 50)
# Out:
#   0%|          | 0/60000 [00:00<?, ?it/s]
# Epoch 1 	Training Loss : 15913.550233840942 	Validation Loss : 1104.1106877326965
# Train Ch Accuracy : 43.84359608990225 	Train Li Accuracy : 0.7175179379484488
# Validation Ch Accuracy : 74.20571428571428 	Validation Li Accuracy : 6.55
#
# Epoch 2 	Training Loss : 3992.6096519231796 	Validation Loss : 393.530552983284
# Train Ch Accuracy : 84.29972654078257 	Train Li Accuracy : 27.964865788311375
# Validation Ch Accuracy : 90.72714285714285 	Validation Li Accuracy : 49.965
#
# Epoch 3 	Training Loss : 1895.138988852501 	Validation Loss : 204.0238807797432
# Train Ch Accuracy : 92.93315666224989 	Train Li Accuracy : 62.6465661641541
# Validation Ch Accuracy : 95.75357142857143 	Validation Li Accuracy : 76.955
#
# Epoch 4 	Training Loss : 1203.9721120893955 	Validation Loss : 152.7436990737915
# Train Ch Accuracy : 95.70751173541244 	Train Li Accuracy : 77.2485978816137
# Validation Ch Accuracy : 96.87214285714286 	Validation Li Accuracy : 83.29
#
# Epoch 5 	Training Loss : 816.1090349704027 	Validation Loss : 111.07239544391632
# Train Ch Accuracy : 97.1575479863187 	Train Li Accuracy : 84.88545546972007
# Validation Ch Accuracy : 97.87714285714286 	Validation Li Accuracy : 88.475
#
# Epoch 6 	Training Loss : 658.6675772219896 	Validation Loss : 110.40787237882614
# Train Ch Accuracy : 97.71470477238121 	Train Li Accuracy : 87.77886113819513
# Validation Ch Accuracy : 97.785 	Validation Li Accuracy : 87.91
#
# Epoch 7 	Training Loss : 369.4093253351748 	Validation Loss : 59.69984696805477
# Train Ch Accuracy : 98.79389841888904 	Train Li Accuracy : 93.36733418335459
# Validation Ch Accuracy : 98.90285714285714 	Validation Li Accuracy : 93.965
#
# Epoch 8 	Training Loss : 315.82801066711545 	Validation Loss : 56.75219210982323
# Train Ch Accuracy : 98.96616463030624 	Train Li Accuracy : 94.28319041309366
# Validation Ch Accuracy : 98.965 	Validation Li Accuracy : 94.39
#
# Epoch 9 	Training Loss : 294.0664746761322 	Validation Loss : 55.18205828592181
# Train Ch Accuracy : 99.0411665053531 	Train Li Accuracy : 94.64153270498429
# Validation Ch Accuracy : 98.99928571428572 	Validation Li Accuracy : 94.38
#
# Epoch 10 	Training Loss : 277.52255815267563 	Validation Loss : 52.500312842428684
# Train Ch Accuracy : 99.10533477622654 	Train Li Accuracy : 95.01570872605149
# Validation Ch Accuracy : 99.06714285714285 	Validation Li Accuracy : 94.83
#
# Epoch 11 	Training Loss : 266.5460361652076 	Validation Loss : 51.42612173035741
# Train Ch Accuracy : 99.14581197863279 	Train Li Accuracy : 95.23321416368742
# Validation Ch Accuracy : 99.08 	Validation Li Accuracy : 94.95
#
# Epoch 12 	Training Loss : 254.0313963573426 	Validation Loss : 50.22890964522958
# Train Ch Accuracy : 99.18462247270467 	Train Li Accuracy : 95.41405201796712
# Validation Ch Accuracy : 99.09571428571428 	Validation Li Accuracy : 95.03
#
# Epoch 13 	Training Loss : 241.52256353758276 	Validation Loss : 49.87625961378217
# Train Ch Accuracy : 99.23498087452187 	Train Li Accuracy : 95.73822678900306
# Validation Ch Accuracy : 99.11214285714286 	Validation Li Accuracy : 95.11
#
# Epoch 14 	Training Loss : 240.93605836480856 	Validation Loss : 49.606884337961674
# Train Ch Accuracy : 99.24712403524374 	Train Li Accuracy : 95.78406126819837
# Validation Ch Accuracy : 99.12 	Validation Li Accuracy : 95.16
#
# Epoch 15 	Training Loss : 239.55414197593927 	Validation Loss : 49.495056468993425
# Train Ch Accuracy : 99.24188580904999 	Train Li Accuracy : 95.77156095569056
# Validation Ch Accuracy : 99.12071428571429 	Validation Li Accuracy : 95.155
#
# Epoch 16 	Training Loss : 239.89954562671483 	Validation Loss : 49.310555689036846
# Train Ch Accuracy : 99.24438587155156 	Train Li Accuracy : 95.75156045567806
# Validation Ch Accuracy : 99.11928571428571 	Validation Li Accuracy : 95.165
#
# Epoch 17 	Training Loss : 235.35321927443147 	Validation Loss : 49.229342848062515
# Train Ch Accuracy : 99.25319561560468 	Train Li Accuracy : 95.8215622057218
# Validation Ch Accuracy : 99.125 	Validation Li Accuracy : 95.195
#
# Epoch 18 	Training Loss : 234.1882774308324 	Validation Loss : 49.00663288682699
# Train Ch Accuracy : 99.25998149953749 	Train Li Accuracy : 95.84489612240306
# Validation Ch Accuracy : 99.12428571428572 	Validation Li Accuracy : 95.195
#
# Epoch 19 	Training Loss : 230.19152844510972 	Validation Loss : 48.96003155782819
# Train Ch Accuracy : 99.26807694001874 	Train Li Accuracy : 95.84572947657024
# Validation Ch Accuracy : 99.12857142857143 	Validation Li Accuracy : 95.2
#
# Epoch 20 	Training Loss : 236.7425929615274 	Validation Loss : 48.92219157144427
# Train Ch Accuracy : 99.25688618405937 	Train Li Accuracy : 95.85072960157338
# Validation Ch Accuracy : 99.12928571428571 	Validation Li Accuracy : 95.22
#
# Epoch 21 	Training Loss : 236.5377987883985 	Validation Loss : 48.92580008506775
# Train Ch Accuracy : 99.24807644000624 	Train Li Accuracy : 95.77406101819213
# Validation Ch Accuracy : 99.12642857142858 	Validation Li Accuracy : 95.215
#
# Epoch 22 	Training Loss : 233.16055371798575 	Validation Loss : 49.04764559492469
# Train Ch Accuracy : 99.27295801442655 	Train Li Accuracy : 95.91239780994525
# Validation Ch Accuracy : 99.12285714285714 	Validation Li Accuracy : 95.155
#
# Epoch 23 	Training Loss : 230.14814458414912 	Validation Loss : 49.007366720587015
# Train Ch Accuracy : 99.27141035668748 	Train Li Accuracy : 95.93489837245932
# Validation Ch Accuracy : 99.12571428571428 	Validation Li Accuracy : 95.19
#
# Epoch 24 	Training Loss : 233.10804043896496 	Validation Loss : 48.87907822802663
# Train Ch Accuracy : 99.26557687751718 	Train Li Accuracy : 95.91323116411243
# Validation Ch Accuracy : 99.13285714285715 	Validation Li Accuracy : 95.24
#
# Epoch 25 	Training Loss : 232.24366514384747 	Validation Loss : 48.96229861676693
# Train Ch Accuracy : 99.27236276144998 	Train Li Accuracy : 95.915731226614
# Validation Ch Accuracy : 99.12714285714286 	Validation Li Accuracy : 95.195
#
# Epoch 26 	Training Loss : 229.21912709623575 	Validation Loss : 48.78434198349714
# Train Ch Accuracy : 99.27569617811874 	Train Li Accuracy : 95.92656483078744
# Validation Ch Accuracy : 99.12785714285714 	Validation Li Accuracy : 95.21
#
# Epoch 27 	Training Loss : 228.75526523776352 	Validation Loss : 48.8830379024148
# Train Ch Accuracy : 99.27545807692812 	Train Li Accuracy : 95.91406451827963
# Validation Ch Accuracy : 99.13142857142857 	Validation Li Accuracy : 95.22
#
# Epoch 28 	Training Loss : 228.76011154055595 	Validation Loss : 48.86994211375713
# Train Ch Accuracy : 99.27391041918905 	Train Li Accuracy : 95.89989749743744
# Validation Ch Accuracy : 99.12857142857143 	Validation Li Accuracy : 95.21
#
# Epoch 29 	Training Loss : 230.76166396588087 	Validation Loss : 48.85243131220341
# Train Ch Accuracy : 99.2743866215703 	Train Li Accuracy : 95.89823078910307
# Validation Ch Accuracy : 99.12642857142858 	Validation Li Accuracy : 95.205
#
# Epoch 30 	Training Loss : 235.65048878453672 	Validation Loss : 48.90494668856263
# Train Ch Accuracy : 99.26188630906249 	Train Li Accuracy : 95.86322991408119
# Validation Ch Accuracy : 99.12714285714286 	Validation Li Accuracy : 95.21
#
# Epoch 31 	Training Loss : 227.81743123568594 	Validation Loss : 48.75987587124109
# Train Ch Accuracy : 99.27926769597812 	Train Li Accuracy : 95.95739893497337
# Validation Ch Accuracy : 99.13071428571429 	Validation Li Accuracy : 95.235
#
# Epoch 32 	Training Loss : 233.9445390701294 	Validation Loss : 48.8222294524312
# Train Ch Accuracy : 99.26117200549061 	Train Li Accuracy : 95.86406326824837
# Validation Ch Accuracy : 99.135 	Validation Li Accuracy : 95.27
#
# Epoch 33 	Training Loss : 232.90591704752296 	Validation Loss : 48.768128737807274
# Train Ch Accuracy : 99.27212466025937 	Train Li Accuracy : 95.9223980599515
# Validation Ch Accuracy : 99.12642857142858 	Validation Li Accuracy : 95.205
#
# Epoch 34 	Training Loss : 230.31507131643593 	Validation Loss : 48.88261505588889
# Train Ch Accuracy : 99.27021985073436 	Train Li Accuracy : 95.88573047659524
# Validation Ch Accuracy : 99.12785714285714 	Validation Li Accuracy : 95.215
#
# Epoch 35 	Training Loss : 230.3617661781609 	Validation Loss : 48.805695969611406
# Train Ch Accuracy : 99.27367231799843 	Train Li Accuracy : 95.92489812245306
# Validation Ch Accuracy : 99.13214285714285 	Validation Li Accuracy : 95.235
#
# Epoch 36 	Training Loss : 232.44329968374223 	Validation Loss : 48.81150380522013
# Train Ch Accuracy : 99.27331516621248 	Train Li Accuracy : 95.89739743493587
# Validation Ch Accuracy : 99.13 	Validation Li Accuracy : 95.235
#
# Epoch 37 	Training Loss : 232.099259018898 	Validation Loss : 48.79627678543329
# Train Ch Accuracy : 99.26819599061405 	Train Li Accuracy : 95.87823028909057
# Validation Ch Accuracy : 99.13071428571429 	Validation Li Accuracy : 95.22
#
# Epoch 38 	Training Loss : 232.9029624098912 	Validation Loss : 48.811586271971464
# Train Ch Accuracy : 99.26998174954373 	Train Li Accuracy : 95.86406326824837
# Validation Ch Accuracy : 99.13357142857143 	Validation Li Accuracy : 95.22
#
# Epoch 39 	Training Loss : 229.19473338499665 	Validation Loss : 48.82094169780612
# Train Ch Accuracy : 99.27593427930937 	Train Li Accuracy : 95.93656508079368
# Validation Ch Accuracy : 99.13285714285715 	Validation Li Accuracy : 95.245
#
# Epoch 40 	Training Loss : 233.77151543274522 	Validation Loss : 48.793343644589186
# Train Ch Accuracy : 99.26271966322967 	Train Li Accuracy : 95.86656333074994
# Validation Ch Accuracy : 99.13214285714285 	Validation Li Accuracy : 95.22
#
# Epoch 41 	Training Loss : 232.55236100032926 	Validation Loss : 48.85189339891076
# Train Ch Accuracy : 99.27188655906873 	Train Li Accuracy : 95.89656408076868
# Validation Ch Accuracy : 99.13214285714285 	Validation Li Accuracy : 95.24
#
# Epoch 42 	Training Loss : 232.29350444674492 	Validation Loss : 48.93174949660897
# Train Ch Accuracy : 99.26379111858749 	Train Li Accuracy : 95.87406351825463
# Validation Ch Accuracy : 99.13 	Validation Li Accuracy : 95.21
#
# Epoch 43 	Training Loss : 232.09054757282138 	Validation Loss : 48.902877524495125
# Train Ch Accuracy : 99.26521972573124 	Train Li Accuracy : 95.87989699742494
# Validation Ch Accuracy : 99.13 	Validation Li Accuracy : 95.22
#
# Epoch 44 	Training Loss : 235.42163037322462 	Validation Loss : 48.88327519595623
# Train Ch Accuracy : 99.2667673834703 	Train Li Accuracy : 95.87489687242181
# Validation Ch Accuracy : 99.13571428571429 	Validation Li Accuracy : 95.265
#
# Epoch 45 	Training Loss : 232.93851758167148 	Validation Loss : 48.83404717594385
# Train Ch Accuracy : 99.26652928227968 	Train Li Accuracy : 95.88073035159212
# Validation Ch Accuracy : 99.13071428571429 	Validation Li Accuracy : 95.235
#
# Epoch 46 	Training Loss : 232.9207051806152 	Validation Loss : 48.858020432293415
# Train Ch Accuracy : 99.26188630906249 	Train Li Accuracy : 95.85239630990775
# Validation Ch Accuracy : 99.125 	Validation Li Accuracy : 95.185
#
# Epoch 47 	Training Loss : 230.9298643246293 	Validation Loss : 48.87166713178158
# Train Ch Accuracy : 99.27319611561718 	Train Li Accuracy : 95.90406426827337
# Validation Ch Accuracy : 99.12642857142858 	Validation Li Accuracy : 95.2
#
# Epoch 48 	Training Loss : 231.81188641488552 	Validation Loss : 48.84258830547333
# Train Ch Accuracy : 99.27129130609218 	Train Li Accuracy : 95.89406401826713
# Validation Ch Accuracy : 99.13285714285715 	Validation Li Accuracy : 95.255
#
# Epoch 49 	Training Loss : 233.98572786338627 	Validation Loss : 48.81880206242204
# Train Ch Accuracy : 99.25974339834687 	Train Li Accuracy : 95.83156245572806
# Validation Ch Accuracy : 99.12785714285714 	Validation Li Accuracy : 95.22
#
# Epoch 50 	Training Loss : 234.23827501386404 	Validation Loss : 48.789767038077116
# Train Ch Accuracy : 99.26117200549061 	Train Li Accuracy : 95.87989699742494
# Validation Ch Accuracy : 99.13 	Validation Li Accuracy : 95.235
